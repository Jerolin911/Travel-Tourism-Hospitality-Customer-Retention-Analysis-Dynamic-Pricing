# %% [markdown]
# Predictive Modeling
#
# Hotel Booking Cancellation Prediction

# %% [markdown]
# 1.Importing libraries including sklearn for modelling

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

# %%
df = pd.read_csv("cleaned_hotel_booking.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
print("Dataset Shape:")
print(df.shape)

print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Shape:
# (87228, 35)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87228 entries, 0 to 87227
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87228 non-null  object
#  1   is_canceled                     87228 non-null  int64
#  2   lead_time                       87228 non-null  int64
#  3   arrival_date_year               87228 non-null  int64
#  4   arrival_date_month              87228 non-null  object
#  5   arrival_date_week_number        87228 non-null  int64
#  6   arrival_date_day_of_month       87228 non-null  int64
#  7   stays_in_weekend_nights         87228 non-null  int64
#  8   stays_in_week_nights            87228 non-null  int64
#  9   adults                          87228 non-null  int64
#  10  children                        87228 non-null  float64
# ...

# %% [markdown]
# 2. Removing the leakage columns

# %%
df_model = df.drop(['arrival_date','reservation_status','reservation_status_date'], axis=1)
print(df_model.shape)
# Out:
# (87228, 32)

# %% [markdown]
# 3. Converting the text columns into numeric values

# %%
le = LabelEncoder()
for col in df_model.select_dtypes(include='object').columns:
    df_model[col] = le.fit_transform(df_model[col])

df_model.head()

# %% [markdown]
# 4. Defining the Features and variables

# %%
#x = independent variables
#y  = target variable

x = df_model.drop('is_canceled', axis=1)
y = df_model['is_canceled']

print("Feature Shape:", x.shape)
print("Target Shape:", y.shape)
# Out:
# Feature Shape: (87228, 31)
# Target Shape: (87228,)

# %% [markdown]
# 5. Train-Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=42, stratify=y)

print("Training Shape:", x_train.shape)
print("Testing Shape:", x_test.shape)
# Out:
# Training Shape: (69782, 31)
# Testing Shape: (17446, 31)

# %% [markdown]
# 6. Forming the baseline of Logistic Regression model

# %%
log_model = LogisticRegression(max_iter=5000,solver='liblinear')

log_model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=5000, solver='liblinear')

# %% [markdown]
# 6.1. Predictions

# %%
y_pred_log = log_model.predict(x_test)

# %%
print("LOGISTIC REGRESSION RESULTS")

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_log))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_log))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_log))

print("\nROC-AUC Score:")
print(roc_auc_score(y_test, y_pred_log))
# Out:
# LOGISTIC REGRESSION RESULTS
#
# Accuracy Score:
# 0.7763957354121288
#
# Confusion Matrix:
# [[11780   864]
#  [ 3037  1765]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86     12644
#            1       0.67      0.37      0.48      4802
#
#     accuracy                           0.78     17446
#    macro avg       0.73      0.65      0.67     17446
# weighted avg       0.76      0.78      0.75     17446
#
#
# ROC-AUC Score:
# 0.6496111896327074

# %% [markdown]
# 7. Random Forest Model

# %%
rf_model = RandomForestClassifier(n_estimators=300, max_depth=15, min_samples_split=5, min_samples_leaf=2, random_state=42, n_jobs=-1)

rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=300, n_jobs=-1, random_state=42)

# %% [markdown]
# 7.1. Predictions

# %%
y_pred_rf = rf_model.predict(x_test)

# %% [markdown]
# 8. Evaluation

# %%
print("RANDOM FOREST RESULTS")

print("\nAccuracy Score:")
print(accuracy_score(y_test, y_pred_rf))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))

print("\nROC-AUC Score:")
print(roc_auc_score(y_test, y_pred_rf))
# Out:
# RANDOM FOREST RESULTS
#
# Accuracy Score:
# 0.8422561045511865
#
# Confusion Matrix:
# [[11886   758]
#  [ 1994  2808]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90     12644
#            1       0.79      0.58      0.67      4802
#
#     accuracy                           0.84     17446
#    macro avg       0.82      0.76      0.78     17446
# weighted avg       0.84      0.84      0.83     17446
#
#
# ROC-AUC Score:
# 0.7624034842067942

# %% [markdown]
# 9. Feature Importance

# %%
feature_importance = pd.Series(rf_model.feature_importances_, index=x.columns)

print(feature_importance.sort_values(ascending=False).head(15))
# Out:
# lead_time                      0.136059
# country                        0.119471
# total_of_special_requests      0.093851
# market_segment                 0.092525
# agent                          0.078361
# required_car_parking_spaces    0.063103
# adr                            0.050471
# deposit_type                   0.039907
# previous_cancellations         0.032305
# customer_type                  0.030307
# arrival_date_year              0.028908
# arrival_date_week_number       0.026066
# booking_changes                0.025099
# total_stay                     0.022701
# arrival_date_day_of_month      0.019502
# dtype: float64

# %% [markdown]
# 10. Comparing the models

# %%
print("MODEL COMPARISON")

print("\nLogistic Regression Accuracy(Percentage wise):")
print(accuracy_score(y_test, y_pred_log) * 100,"%")

print("\nRandom Forest Accuracy:")
print(accuracy_score(y_test, y_pred_rf) * 100,"%")
# Out:
# MODEL COMPARISON
#
# Logistic Regression Accuracy(Percentage wise):
# 77.63957354121288 %
#
# Random Forest Accuracy:
# 84.22561045511866 %
